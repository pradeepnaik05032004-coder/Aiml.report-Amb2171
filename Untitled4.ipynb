# %%
import pandas as pd
#farm dataset with many tracked factors data={
    "rainfall_mm":[200,180,220,210,190,230],
    "soil_moisture":[30,28,35,33,29,36],
    "wind_speed":[80,]}
