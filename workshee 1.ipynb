# %%
n=int(input("enter the soil nitrogen level:"))
print("soil nitrogen level:",n)
if n<100:
  print("recommendtion:apply high nitrogen fertilizer \ncost:2000/bag")
elif 100<=n<=250:
  print("recommendtion:apply medium nitrogen fertilizer \ncost:1000/bag\nmessage:your soil has adequate nitrogen but needs slight supplementation")
else:
  print("recommendation:no fertilizer needed\nmessage:soil is healhy")
# Out:
# enter the soil nitrogen level:140
# soil nitrogen level: 140
# recommendtion:apply medium nitrogen fertilizer
# cost:1000/bag
# message:your soil has adequate nitrogen but needs slight supplementation

# %%
crop=("input (enter the crop)")
moist=float(input("input (enter the soil moisture)"))
temperature=float("enter the temperature condition")
print("cop,=crop","moisture,=moisture",temperature,="temperature")
if crop=="rice"and
